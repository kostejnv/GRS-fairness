# %%
import mlflow
import pandas as pd

uri = 'file:///Users/vitkostejn/school/diploma_thesis/code/mlruns' # Set your MLflow tracking URI here
mlflow.set_tracking_uri(uri)

# %%
import pickle

def get_metric_data(run, metric='NDCG20'):
    artifact_path = run['artifact_uri'].replace('file://', '') + '/logs.pkl'
    with open(artifact_path, 'rb') as f:
        data = pickle.load(f)
    return data[metric]

# %%
aggregation_mapping = {
    "average": "Avg",
    "max": "Max",
    "common_features": "ComF",
    "wcom": "WCom",
    "topk": "TopK",
}

def get_method_name(row):
    method = row['params.recommender_strategy']
    if method == "SAE":
        aggregation = row['params.SAE_fusion_strategy']
        method += "-" + aggregation_mapping.get(aggregation, aggregation)
    return method.replace('_', '-')

# %%
experiment_id = '523100174176986081'
# params.group_set = 'test' and params.user_set = 'test'
runs = mlflow.search_runs(
    experiment_ids=[experiment_id],
    filter_string="params.group_set = 'test' and params.user_set = 'test'",
    output_format="pandas",
)

# %%
data = []

metrics = ['NDCG20_com', 'NDCG20_min', 'NDCG20_mean', 'Popularity']
add_name_metrics = ['Group_NDCG', 'User_NDCG_Mins', 'User_NDCG_Means', 'Popularity']
for i, run in runs.iterrows():
    if run['status'] == 'FAILED':
        print(f"Skipping run {run['run_id']} due to failure.")
        continue
    method = get_method_name(run)
    print(f"Processing run: {method}")
    
    metrics_data = {}
    for metric, add_metric in zip(metrics, add_name_metrics):
        metrics_data[metric] = get_metric_data(run, add_metric)
    for i in range(metrics_data[metrics[0]].shape[0]):
        row = {
            'Method': method,
            'Group_type': run['params.group_type'],
            'Group_index': i,
        }
        for metric in metrics:
            row[metric.replace('20', '')] = float(metrics_data[metric][i])
        data.append(row)
df = pd.DataFrame(data)
print(len(df), "rows in the dataframe")
df.tail()
df.to_csv("test-extended-results.csv", index=False)
# Out:
# Skipping run 17a301fd2d14471ea08d5e39bf41c047 due to failure.
# Processing run: MPL
# Processing run: EPFuzzDA
# Processing run: GFAR
# Processing run: LMS
# Processing run: ADD
# Processing run: POPULAR
# Processing run: MPL
# Processing run: EPFuzzDA
# Processing run: GFAR
# Processing run: LMS
# Processing run: ADD
# Processing run: POPULAR
# Processing run: MPL
# Processing run: EPFuzzDA
# Processing run: GFAR
# Processing run: LMS
# Processing run: ADD
# Processing run: POPULAR
# Processing run: SAE-WCom
# Processing run: SAE-TopK
# Processing run: SAE-Max
# Processing run: SAE-ComF
# Processing run: SAE-Avg
# Processing run: SAE-WCom
# /var/folders/11/x3r2lw756bs10f4yq3hp5cqh0000gn/T/ipykernel_2117/1983316202.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   row[metric.replace('20', '')] = float(metrics_data[metric][i])
# Processing run: SAE-TopK
# Processing run: SAE-Max
# Processing run: SAE-ComF
# Processing run: SAE-Avg
# Processing run: SAE-WCom
# Processing run: SAE-TopK
# Processing run: SAE-Max
# Processing run: SAE-ComF
# Processing run: SAE-Avg
# Processing run: ELSA-INT
# Processing run: ELSA-INT
# Processing run: ELSA-INT
# Processing run: ELSA
# Processing run: ELSA
# Processing run: ELSA
# 39000 rows in the dataframe

# %%
grouped_df = df.groupby(['Method', 'Group_type']).agg(list).reset_index()

# %%
from statistics import mean
from scipy import stats


group_types = ['sim', 'random', 'outlier']
metrics = ["NDCG20_com", "NDCG20_min", "NDCG20_mean", "Popularity"]

significance_results = {}

for group_type in group_types:
    curr_runs = grouped_df[grouped_df['Group_type'] == group_type]
    for metric in metrics:
        best_method = max(curr_runs['Method'].values, key=lambda x: mean(curr_runs[curr_runs['Method'] == x][metric].values[0]))
        best_list = curr_runs[curr_runs['Method'] == best_method][metric].values[0]
        for method in curr_runs['Method'].values:
            approach_list = curr_runs[curr_runs['Method'] == method][metric].values[0]
            t_stat, p_value = stats.ttest_rel(best_list, approach_list, alternative='greater')
            significance_results[(group_type, method, metric)] = p_value
            
for (group_type, method, metric), p_value in significance_results.items():
    print(group_type, method, metric, p_value)
# Out:
# sim ADD NDCG20_com 0.07485615610541298
# sim ELSA NDCG20_com 2.982250416635818e-26
# sim ELSA-INT NDCG20_com 4.42966209040028e-139
# sim EPFuzzDA NDCG20_com 7.859371125191554e-05
# sim GFAR NDCG20_com 8.279333589164189e-121
# sim LMS NDCG20_com 2.658315835942324e-09
# sim MPL NDCG20_com 4.7348195943930475e-206
# sim POPULAR NDCG20_com 1.640203932405366e-192
# sim SAE-Avg NDCG20_com 0.060860857596647326
# sim SAE-ComF NDCG20_com 7.725558391970059e-33
# sim SAE-Max NDCG20_com 1.9089643007368657e-14
# sim SAE-TopK NDCG20_com nan
# sim SAE-WCom NDCG20_com 9.134073778165553e-07
# sim ADD NDCG20_min 0.12373727765298345
# sim ELSA NDCG20_min 1.1172300348415418e-53
# sim ELSA-INT NDCG20_min 2.063132323632808e-138
# sim EPFuzzDA NDCG20_min 0.002223870170575656
# sim GFAR NDCG20_min 5.798326800638472e-66
# sim LMS NDCG20_min 1.4764016929082478e-23
# sim MPL NDCG20_min 4.7910368678862814e-142
# sim POPULAR NDCG20_min 1.225707211353363e-209
# sim SAE-Avg NDCG20_min 0.4231522212728437
# sim SAE-ComF NDCG20_min 5.531938918740981e-38
# sim SAE-Max NDCG20_min 7.16062504926912e-08
# sim SAE-TopK NDCG20_min nan
# sim SAE-WCom NDCG20_min 3.600669373307983e-06
# sim ADD NDCG20_mean nan
# sim ELSA NDCG20_mean 4.2160066010858785e-16
# sim ELSA-INT NDCG20_mean 3.9550766668524736e-141
# sim EPFuzzDA NDCG20_mean 3.2881538773367537e-25
# sim GFAR NDCG20_mean 7.969304120266373e-168
# sim LMS NDCG20_mean 2.135263320626548e-82
# sim MPL NDCG20_mean 5.268492632763191e-234
# sim POPULAR NDCG20_mean 1.7463579979163317e-231
# sim SAE-Avg NDCG20_mean 0.033322582307420925
# sim SAE-ComF NDCG20_mean 3.5583568012178786e-61
# sim SAE-Max NDCG20_mean 3.3538132839203127e-23
# sim SAE-TopK NDCG20_mean 0.30973727339909074
# sim SAE-WCom NDCG20_mean 6.253364577517572e-13
# sim ADD Popularity 2.9501539791956136e-232
# sim ELSA Popularity 2.663632354912521e-230
# sim ELSA-INT Popularity 8.73285659048292e-289
# sim EPFuzzDA Popularity 2.3735352619678888e-238
# sim GFAR Popularity 1.527240272137005e-306
# sim LMS Popularity 9.446806107268187e-257
# sim MPL Popularity 0.0
# sim POPULAR Popularity nan
# sim SAE-Avg Popularity 1.2104351244994757e-231
# sim SAE-ComF Popularity 1.90683585611835e-243
# sim SAE-Max Popularity 3.3476138854294517e-227
# sim SAE-TopK Popularity 5.25801193429102e-239
# sim SAE-WCom Popularity 1.5562763788097665e-243
# random ADD NDCG20_com 0.05806636192280653
# random ELSA NDCG20_com 7.271336702857908e-36
# random ELSA-INT NDCG20_com 9.383034369282112e-153
# random EPFuzzDA NDCG20_com 3.140982106841815e-05
# random GFAR NDCG20_com 1.283125820641084e-152
# random LMS NDCG20_com 1.3007668256945193e-11
# random MPL NDCG20_com 1.5869240659892364e-244
# random POPULAR NDCG20_com 4.864173563204456e-142
# random SAE-Avg NDCG20_com 0.023627333234580383
# random SAE-ComF NDCG20_com 2.8826738857141483e-68
# random SAE-Max NDCG20_com 5.415089403120492e-09
# random SAE-TopK NDCG20_com nan
# random SAE-WCom NDCG20_com 1.0115237679730603e-05
# random ADD NDCG20_min 0.03737441063226183
# random ELSA NDCG20_min 1.8912643581335147e-57
# random ELSA-INT NDCG20_min 1.8488187994429607e-153
# random EPFuzzDA NDCG20_min 0.010530440551411283
# random GFAR NDCG20_min 2.9145984173769213e-88
# random LMS NDCG20_min 1.0930558259806564e-40
# random MPL NDCG20_min 1.1027181948680394e-165
# random POPULAR NDCG20_min 3.449071988618772e-147
# random SAE-Avg NDCG20_min 0.25748725140593454
# random SAE-ComF NDCG20_min 2.4804899972737778e-56
# random SAE-Max NDCG20_min 0.028272868859477388
# random SAE-TopK NDCG20_min nan
# random SAE-WCom NDCG20_min 6.7572542550277755e-09
# random ADD NDCG20_mean 0.014286511839863236
# random ELSA NDCG20_mean 4.34393485093802e-23
# random ELSA-INT NDCG20_mean 2.187774361584391e-146
# random EPFuzzDA NDCG20_mean 2.1550118532543284e-32
# random GFAR NDCG20_mean 5.365283587651331e-195
# random LMS NDCG20_mean 2.745190363132919e-99
# random MPL NDCG20_mean 4.650631306473607e-258
# random POPULAR NDCG20_mean 5.427817033293423e-190
# random SAE-Avg NDCG20_mean 4.1808568340730086e-05
# random SAE-ComF NDCG20_mean 2.149588125089858e-110
# random SAE-Max NDCG20_mean 2.3734756152495504e-21
# random SAE-TopK NDCG20_mean nan
# random SAE-WCom NDCG20_mean 1.2734032962405084e-12
# random ADD Popularity 7.667267896358351e-254
# random ELSA Popularity 1.4629246792580402e-227
# random ELSA-INT Popularity 2.9837310421047597e-295
# random EPFuzzDA Popularity 2.3313927253461352e-264
# random GFAR Popularity 0.0
# random LMS Popularity 8.38504375160925e-284
# random MPL Popularity 0.0
# random POPULAR Popularity nan
# random SAE-Avg Popularity 5.4011091947061396e-250
# random SAE-ComF Popularity 2.053458767690938e-276
# random SAE-Max Popularity 5.240201839800123e-237
# random SAE-TopK Popularity 1.7307582766138858e-248
# random SAE-WCom Popularity 3.426456378040359e-253
# outlier ADD NDCG20_com 5.252898455744844e-15
# outlier ELSA NDCG20_com 1.0955723889462536e-107
# outlier ELSA-INT NDCG20_com 0.0
# outlier EPFuzzDA NDCG20_com 3.782690401940958e-38
# outlier GFAR NDCG20_com 2.2715046166593998e-197
# outlier LMS NDCG20_com 7.22834885250168e-69
# outlier MPL NDCG20_com 4.501575482080223e-306
# outlier POPULAR NDCG20_com 2.6028578849209514e-54
# outlier SAE-Avg NDCG20_com 4.0943396655174775e-11
# outlier SAE-ComF NDCG20_com 9.767268041218047e-109
# outlier SAE-Max NDCG20_com 4.900114345921205e-12
# outlier SAE-TopK NDCG20_com nan
# outlier SAE-WCom NDCG20_com 8.692814782251915e-20
# outlier ADD NDCG20_min 1.0681444408163396e-11
# outlier ELSA NDCG20_min 6.272414533861437e-125
# outlier ELSA-INT NDCG20_min 0.0
# outlier EPFuzzDA NDCG20_min 2.428127837392459e-15
# outlier GFAR NDCG20_min 2.369268425600216e-103
# outlier LMS NDCG20_min 8.98301830975694e-91
# outlier MPL NDCG20_min 9.447732867898481e-212
# outlier POPULAR NDCG20_min 2.3715595444604078e-61
# outlier SAE-Avg NDCG20_min 1.1160951972387423e-07
# outlier SAE-ComF NDCG20_min 7.618012522523725e-105
# outlier SAE-Max NDCG20_min nan
# outlier SAE-TopK NDCG20_min 0.4511107753734108
# outlier SAE-WCom NDCG20_min 2.521708292705252e-17
# outlier ADD NDCG20_mean 8.598097510718915e-18
# outlier ELSA NDCG20_mean 1.576359904213178e-107
# outlier ELSA-INT NDCG20_mean 0.0
# outlier EPFuzzDA NDCG20_mean 3.3051528296837207e-131
# outlier GFAR NDCG20_mean 9.184352677e-315
# outlier LMS NDCG20_mean 2.2565126368766905e-223
# outlier MPL NDCG20_mean 0.0
# outlier POPULAR NDCG20_mean 2.289813764825305e-109
# outlier SAE-Avg NDCG20_mean 1.3330122440938095e-13
# outlier SAE-ComF NDCG20_mean 1.0491324804750313e-189
# outlier SAE-Max NDCG20_mean 6.801177052628013e-39
# outlier SAE-TopK NDCG20_mean nan
# outlier SAE-WCom NDCG20_mean 2.51230226139091e-28
# outlier ADD Popularity 9.767457495907256e-272
# outlier ELSA Popularity 0.0
# outlier ELSA-INT Popularity 0.0
# outlier EPFuzzDA Popularity 0.0
# outlier GFAR Popularity 0.0
# outlier LMS Popularity 0.0
# outlier MPL Popularity 0.0
# outlier POPULAR Popularity nan
# outlier SAE-Avg Popularity 2.983090704120081e-256
# outlier SAE-ComF Popularity 0.0
# outlier SAE-Max Popularity 4.5807409671840526e-275
# outlier SAE-TopK Popularity 1.1899263444957752e-252
# outlier SAE-WCom Popularity 1.0785060825035623e-251

# %%
from scipy import stats

significance = []

group_types = ['sim', 'random', 'outlier']

add_name_metrics = ['Group_NDCG', 'User_NDCG_Mins', 'User_NDCG_Means', 'Popularity']
official_metrics = ['$NDCG_{com}$', '$NDCG_{min}$', '$NDCG_{mean}$', 'Popularity']
for group_type in group_types:
    print(f"Group Type: {group_type.upper()}")
    group_runs = [run for run in runs if run.data.params.get('group_type') == group_type]
    print(f"Number of runs: {len(group_runs)}")
    for metric, add_name_metric, official_metric in zip(metrics, add_name_metrics, official_metrics):
        metric_data = get_metric_data(group_runs, metric=add_name_metric)
        ff = min if official_metric == 'Popularity' else max
        best_run = ff(metric_data.items(), key=lambda x: x[1].mean())
        print(f"Best {add_name_metric} for {group_type} groups: {best_run[0]} with mean {best_run[1].mean():.3f} and std {best_run[1].std():.3f}")
        
        # Get significance to the best run
        for i, run in enumerate(group_runs):
            strategy = get_method_name(run)
            data = {
                'Group Type': group_type,
                'Metric': official_metric,
                'Strategy': strategy,
                'Value': metric_data[strategy].mean(),
            }
            curr_results = metric_data[strategy]
            alternative = 'greater' if official_metric != 'Popularity' else 'less'
            t_stat, p_val = stats.ttest_rel(best_run[1].squeeze(), curr_results.squeeze(), alternative=alternative)
            print(f"{strategy}: t = {t_stat:.3f}  p = {p_val:.4f}")
            data['p-value'] = p_val
            if p_val <= 0.05 and strategy != best_run[0]:
                data['Significant'] = True
            else:
                data['Significant'] = False
            significance.append(data)
# Out:
# Group Type: SIM
# Number of runs: 13
# Best Group_NDCG for sim groups: SAE-TopK with mean 0.639 and std 0.175
# MPL: t = 39.420  p = 0.0000
# EPFuzzDA: t = 3.794  p = 0.0001
# GFAR: t = 26.926  p = 0.0000
# LMS: t = 5.889  p = 0.0000
# ADD: t = 1.442  p = 0.0749
# POPULAR: t = 37.411  p = 0.0000
# SAE-WCom: t = 4.800  p = 0.0000
# SAE-TopK: t = nan  p = nan
# SAE-Max: t = 7.679  p = 0.0000
# SAE-ComF: t = 12.313  p = 0.0000
# SAE-Avg: t = 1.549  p = 0.0609
# ELSA-INT: t = 29.603  p = 0.0000
# ELSA: t = 10.837  p = 0.0000
# Best User_NDCG_Mins for sim groups: SAE-TopK with mean 0.558 and std 0.125
# MPL: t = 30.035  p = 0.0000
# EPFuzzDA: t = 2.851  p = 0.0022
# GFAR: t = 18.454  p = 0.0000
# LMS: t = 10.187  p = 0.0000
# ADD: t = 1.157  p = 0.1237
# POPULAR: t = 39.956  p = 0.0000
# SAE-WCom: t = 4.511  p = 0.0000
# SAE-TopK: t = nan  p = nan
# SAE-Max: t = 5.299  p = 0.0000
# SAE-ComF: t = 13.381  p = 0.0000
# SAE-Avg: t = 0.194  p = 0.4232
# ELSA-INT: t = 29.505  p = 0.0000
# ELSA: t = 16.341  p = 0.0000
# Best User_NDCG_Means for sim groups: ADD with mean 0.704 and std 0.078
# MPL: t = 43.644  p = 0.0000
# EPFuzzDA: t = 10.590  p = 0.0000
# GFAR: t = 33.790  p = 0.0000
# LMS: t = 21.112  p = 0.0000
# ADD: t = nan  p = nan
# POPULAR: t = 43.258  p = 0.0000
# SAE-WCom: t = 7.192  p = 0.0000
# SAE-TopK: t = 0.497  p = 0.3097
# SAE-Max: t = 10.099  p = 0.0000
# SAE-ComF: t = 17.647  p = 0.0000
# SAE-Avg: t = 1.836  p = 0.0333
# ELSA-INT: t = 29.902  p = 0.0000
# ELSA: t = 8.182  p = 0.0000
# Best Popularity for sim groups: ELSA-INT with mean 0.426 and std 0.149
# MPL: t = -8.204  p = 0.0000
# EPFuzzDA: t = -26.193  p = 0.0000
# GFAR: t = -16.948  p = 0.0000
# LMS: t = -18.419  p = 0.0000
# ADD: t = -29.081  p = 0.0000
# POPULAR: t = -52.332  p = 0.0000
# SAE-WCom: t = -22.736  p = 0.0000
# SAE-TopK: t = -27.637  p = 0.0000
# SAE-Max: t = -30.541  p = 0.0000
# SAE-ComF: t = -13.145  p = 0.0000
# SAE-Avg: t = -27.181  p = 0.0000
# ELSA-INT: t = nan  p = nan
# ELSA: t = -32.240  p = 0.0000
# Group Type: RANDOM
# Number of runs: 13
# Best Group_NDCG for random groups: SAE-TopK with mean 0.635 and std 0.176
# MPL: t = 45.266  p = 0.0000
# EPFuzzDA: t = 4.019  p = 0.0000
# GFAR: t = 31.575  p = 0.0000
# LMS: t = 6.744  p = 0.0000
# ADD: t = 1.573  p = 0.0581
# POPULAR: t = 30.034  p = 0.0000
# SAE-WCom: t = 4.283  p = 0.0000
# SAE-TopK: t = nan  p = nan
# SAE-Max: t = 5.766  p = 0.0000
# SAE-ComF: t = 18.837  p = 0.0000
# SAE-Avg: t = 1.986  p = 0.0236
# ELSA-INT: t = 31.594  p = 0.0000
# ELSA: t = 12.949  p = 0.0000
# Best User_NDCG_Mins for random groups: SAE-TopK with mean 0.538 and std 0.120
# MPL: t = 33.478  p = 0.0000
# EPFuzzDA: t = 2.311  p = 0.0105
# GFAR: t = 22.027  p = 0.0000
# LMS: t = 13.920  p = 0.0000
# ADD: t = 1.784  p = 0.0374
# POPULAR: t = 30.784  p = 0.0000
# SAE-WCom: t = 5.727  p = 0.0000
# SAE-TopK: t = nan  p = nan
# SAE-Max: t = 1.909  p = 0.0283
# SAE-ComF: t = 16.810  p = 0.0000
# SAE-Avg: t = 0.651  p = 0.2575
# ELSA-INT: t = 31.697  p = 0.0000
# ELSA: t = 17.005  p = 0.0000
# Best User_NDCG_Means for random groups: SAE-TopK with mean 0.692 and std 0.076
# MPL: t = 47.383  p = 0.0000
# EPFuzzDA: t = 12.217  p = 0.0000
# GFAR: t = 37.778  p = 0.0000
# LMS: t = 23.716  p = 0.0000
# ADD: t = 2.193  p = 0.0143
# POPULAR: t = 37.039  p = 0.0000
# SAE-WCom: t = 7.089  p = 0.0000
# SAE-TopK: t = nan  p = nan
# SAE-Max: t = 9.630  p = 0.0000
# SAE-ComF: t = 25.384  p = 0.0000
# SAE-Avg: t = 3.950  p = 0.0000
# ELSA-INT: t = 30.668  p = 0.0000
# ELSA: t = 10.071  p = 0.0000
# Best Popularity for random groups: ELSA-INT with mean 0.414 and std 0.154
# MPL: t = -11.852  p = 0.0000
# EPFuzzDA: t = -33.574  p = 0.0000
# GFAR: t = -20.911  p = 0.0000
# LMS: t = -27.122  p = 0.0000
# ADD: t = -35.412  p = 0.0000
# POPULAR: t = -53.401  p = 0.0000
# SAE-WCom: t = -31.865  p = 0.0000
# SAE-TopK: t = -35.899  p = 0.0000
# SAE-Max: t = -35.057  p = 0.0000
# SAE-ComF: t = -21.847  p = 0.0000
# SAE-Avg: t = -34.240  p = 0.0000
# ELSA-INT: t = nan  p = nan
# ELSA: t = -39.185  p = 0.0000
# Group Type: OUTLIER
# Number of runs: 13
# Best Group_NDCG for outlier groups: SAE-TopK with mean 0.543 and std 0.200
# MPL: t = 55.214  p = 0.0000
# EPFuzzDA: t = 13.415  p = 0.0000
# GFAR: t = 38.129  p = 0.0000
# LMS: t = 18.936  p = 0.0000
# ADD: t = 7.852  p = 0.0000
# POPULAR: t = 16.454  p = 0.0000
# SAE-WCom: t = 9.218  p = 0.0000
# SAE-TopK: t = nan  p = nan
# SAE-Max: t = 6.891  p = 0.0000
# SAE-ComF: t = 25.136  p = 0.0000
# SAE-Avg: t = 6.568  p = 0.0000
# ELSA-INT: t = 58.702  p = 0.0000
# ELSA: t = 24.980  p = 0.0000
# Best User_NDCG_Mins for outlier groups: SAE-Max with mean 0.495 and std 0.137
# MPL: t = 40.272  p = 0.0000
# EPFuzzDA: t = 7.954  p = 0.0000
# GFAR: t = 24.329  p = 0.0000
# LMS: t = 22.415  p = 0.0000
# ADD: t = 6.774  p = 0.0000
# POPULAR: t = 17.677  p = 0.0000
# SAE-WCom: t = 8.538  p = 0.0000
# SAE-TopK: t = 0.123  p = 0.4511
# SAE-Max: t = nan  p = nan
# SAE-ComF: t = 24.554  p = 0.0000
# SAE-Avg: t = 5.215  p = 0.0000
# ELSA-INT: t = 59.924  p = 0.0000
# ELSA: t = 27.533  p = 0.0000
# Best User_NDCG_Means for outlier groups: SAE-TopK with mean 0.672 and std 0.086
# MPL: t = 62.988  p = 0.0000
# EPFuzzDA: t = 28.453  p = 0.0000
# GFAR: t = 56.691  p = 0.0000
# LMS: t = 42.024  p = 0.0000
# ADD: t = 8.670  p = 0.0000
# POPULAR: t = 25.230  p = 0.0000
# SAE-WCom: t = 11.318  p = 0.0000
# SAE-TopK: t = nan  p = nan
# SAE-Max: t = 13.564  p = 0.0000
# SAE-ComF: t = 36.997  p = 0.0000
# SAE-Avg: t = 7.411  p = 0.0000
# ELSA-INT: t = 62.529  p = 0.0000
# ELSA: t = 24.956  p = 0.0000
# Best Popularity for outlier groups: ELSA-INT with mean 0.174 and std 0.125
# MPL: t = -40.360  p = 0.0000
# EPFuzzDA: t = -69.857  p = 0.0000
# GFAR: t = -57.837  p = 0.0000
# LMS: t = -55.218  p = 0.0000
# ADD: t = -68.244  p = 0.0000
# POPULAR: t = -125.880  p = 0.0000
# SAE-WCom: t = -68.246  p = 0.0000
# SAE-TopK: t = -80.336  p = 0.0000
# SAE-Max: t = -69.574  p = 0.0000
# SAE-ComF: t = -43.772  p = 0.0000
# SAE-Avg: t = -67.280  p = 0.0000
# ELSA-INT: t = nan  p = nan
# ELSA: t = -57.462  p = 0.0000

# %%
df = pd.DataFrame(significance).sort_values(by=['Significant'], ascending=True)
df.head(20)
df.to_csv('paper/significance.csv', index=False)
